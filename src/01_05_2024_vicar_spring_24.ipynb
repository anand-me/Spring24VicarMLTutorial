# %% [markdown]
# Tutorials on Python
#
#  *Why Python for Machine Learning?* 🐍
#
# In the realm of machine learning, Python has emerged as a dominant programming language. Its versatility, extensive library support, and community-driven development make it an essential skill for anyone looking to stay abreast of evolving trends in the field.
#
# 1.   How can we start off by simply prining some text/sentence on python, then we will look at basic operations such as:
# *   List
# *   Tuple
# *   Dictionary
# 2.   Simple Algebric Operations

# %%
#To print text or a sentence in Python, you can use the print() function. Here's a simple example:
print("Hello, Members of CTML!")
# Out:
# Hello, Members of CTML!

# %%
# Now, I want to split the sentence into individual words and then print each word separately.
sentence = "Hello, Members of CTML!"
words = sentence.split()

for word in words:
    print(word)
# Out:
# Hello,
# Members
# of
# CTML!

# %%
x1 = 'Hello'
x2 = 'Members'
x3 = 'of'
x4 = 'CTML'

y = 'Hello,\n Members\n of\n CTML!'

x = x1+'.'+x2+'.'+x3+'.'+x4
print (x)
print(y)
# Here, I show the the concatenation of individual words with dots and
# printing of both the concatenated string (x) and a multi-line representation of the original sentence (y).
# The code uses string concatenation and line breaks to achieve the desired output.
# Out:
# Hello.Members.of.CTML
# Hello,
#  Members
#  of
#  CTML!

# %% [markdown]
#  # *Let's work on **lists**

# %%
# Creating the List
members_of_CTML = ['Akshay', 'Alireza', 'Gautam', 'Aojia', 'Brian', 'Shirin', 'Shahriar', 'KSH']
# Accessing Elements
print("First member:", members_of_CTML[0])
print("Second member:", members_of_CTML[1])
# Out:
# First member: Akshay
# Second member: Alireza

# %%
# Modifying Elements
members_of_CTML[7] = 'Jason'
print("Updated list:", members_of_CTML)
# Out:
# Updated list: ['Akshay', 'Alireza', 'Gautam', 'Aojia', 'Brian', 'Shirin', 'Shahriar', 'Jason']

# %%
# Slicing the List
sliced_list = members_of_CTML[2:5]
print("Sliced list:", sliced_list)
# Out:
# Sliced list: ['Gautam', 'Aojia', 'Brian']

# %%
# Removing Elements
removed_member = members_of_CTML.pop(6)
print("Removed member at index 3:", removed_member)
print("Updated list after pop:", members_of_CTML)
# Out:
# Removed member at index 3: Shahriar
# Updated list after pop: ['Akshay', 'Alireza', 'Gautam', 'Aojia', 'Brian', 'Shirin', 'Jason', 'NewMember', 'New Postdoc', 'New Postdoc', 'NewPostdoc', 'NewPostdoc', 'NewMember in CTML']

# %%
# Checking if an Element is in the List
if 'Brian' in members_of_CTML:
    print("Yes, 'Brian' is in the list.")
else:
    print("No, 'Brian' is not in the list.")
# Out:
# Yes, 'Brian' is in the list.

# %% [markdown]
# # *Now is the time to play with **Tuples**

# %%
# Creating the Tuple
members_of_CTML_tuple = ('Akshay', 'Alireza', 'Gautam', 'Aojia', 'Brian', 'Shirin', 'Shahriar', 'KSH')
# Accessing Elements
print("First member:", members_of_CTML_tuple[0])
print("Second member:", members_of_CTML_tuple[1])
# Out:
# First member: Akshay
# Second member: Alireza

# %% [markdown]
# # *Note: Since tuples are immutable, modifying and adding elements directly is not possible.*

# %%
# Slicing the Tuple
sliced_tuple = members_of_CTML_tuple[2:5]
print("Sliced tuple:", sliced_tuple)
# Out:
# Sliced tuple: ('Gautam', 'Aojia', 'Brian')

# %%
# Iterating Through the Tuple
print("Iterating through the tuple:")
for member in members_of_CTML_tuple:
    print(member)
# Out:
# Iterating through the tuple:
# Akshay
# Alireza
# Gautam
# Aojia
# Brian
# Shirin
# Shahriar
# KSH

# %%
# Checking if an Element is in the Tuple
if 'Brian' in members_of_CTML_tuple:
    print("Yes, 'Brian' is in the tuple.")
else:
    print("No, 'Brian' is not in the tuple.")

# Finding the Length of the Tuple
tuple_length = len(members_of_CTML_tuple)
print("Length of the tuple:", tuple_length)
# Out:
# Yes, 'Brian' is in the tuple.
# Length of the tuple: 8

# %% [markdown]
#  # *Now, is the time to look at **dictionary**

# %%
# Creating the Dictionary with Roles (I guess don't get mad or excited this is hypothetical roles :)
members_of_CTML_dict = {
    'Akshay': 'Data Scientist',
    'Alireza': 'Machine Learning Engineer',
    'Gautam': 'CFD Engineer',
    'Aojia': 'Software Developer',
    'Brian': 'Robotics Engineer',
    'Shirin': 'AI Engineer',
    'Shahriar': 'CFD Developer',
    'KSH': 'Scientist'
}

# %%
# Accessing Elements
print("Role of Akshay:", members_of_CTML_dict['Akshay'])
print("Role of Brian:", members_of_CTML_dict['Brian'])
# Out:
# Role of Akshay: Data Scientist
# Role of Brian: Robotics Engineer

# %%
# Modifying Elements: Alireza is promoted to AI Engineer (lots of work on unsupervised ML and DL :)
members_of_CTML_dict['Alireza'] = 'AI Researcher'
print("Updated dictionary:", members_of_CTML_dict)
# Out:
# Updated dictionary: {'Akshay': 'Data Scientist', 'Alireza': 'AI Researcher', 'Gautam': 'CFD Engineer', 'Aojia': 'Software Developer', 'Brian': 'Robotics Engineer', 'Shirin': 'AI Engineer', 'Shahriar': 'CFD Developer', 'KSH': 'Scientist'}

# %%
# Adding Elements : Potentially PostDoc
members_of_CTML_dict['NewMember'] = 'Software Engineer'
print("Dictionary after adding 'NewMember':", members_of_CTML_dict)
# Out:
# Dictionary after adding 'NewMember': {'Akshay': 'Data Scientist', 'Alireza': 'AI Researcher', 'Gautam': 'CFD Engineer', 'Aojia': 'Software Developer', 'Brian': 'Robotics Engineer', 'Shirin': 'AI Engineer', 'Shahriar': 'CFD Developer', 'KSH': 'Scientist', 'NewMember': 'Software Engineer'}

# %%
# Removing Elements (Rmoved Akshay)
removed_member_role = members_of_CTML_dict.pop('Akshay')
print("Removed role of Akshay:", removed_member_role)
print("Updated dictionary after pop:", members_of_CTML_dict)
# Out:
# Removed role of Akshay: Data Scientist
# Updated dictionary after pop: {'Alireza': 'AI Researcher', 'Gautam': 'CFD Engineer', 'Aojia': 'Software Developer', 'Brian': 'Robotics Engineer', 'Shirin': 'AI Engineer', 'Shahriar': 'CFD Developer', 'KSH': 'Scientist', 'NewMember': 'Software Engineer'}

# %%
# Iterating Through the Dictionary
print("Iterating through the dictionary:")
for member, role in members_of_CTML_dict.items():
    print(f"{member}: {role}")
# Out:
# Iterating through the dictionary:
# Alireza: AI Researcher
# Gautam: CFD Engineer
# Aojia: Software Developer
# Brian: Robotics Engineer
# Shirin: AI Engineer
# Shahriar: CFD Developer
# KSH: Scientist
# NewMember: Software Engineer

# %%
# Checking if a Key is in the Dictionary
if 'Shirin' in members_of_CTML_dict:
    print("Yes, 'Shirin' is in the dictionary.")
else:
    print("No, 'Shirin' is not in the dictionary.")
# Out:
# Yes, 'Shirin' is in the dictionary.

# %% [markdown]
# # *Simple **algebraic operations using intergers and floats**

# %%
# Integer and Floating-point Operations
integer_result = 5 + 3     # Addition
float_result = 5.0 - 2.5   # Subtraction
mixed_result = 4 * 1.5     # Multiplication
# Division
integer_division = 7 / 2  # Integer division
float_division = 7 / 2.0   # Floating-point division
# Exponentiation
power_result = 2 ** 3      # 2 raised to the power of 3
# Modulo (Remainder)
remainder = 10 % 3

# %%
# Printing Results
print("Integer Result:", integer_result)
print("Float Result:", float_result)
print("Mixed Result:", mixed_result)
print("Integer Division:", integer_division)
print("Float Division:", float_division)
print("Power Result:", power_result)
print("Remainder:", remainder)
# Out:
# Integer Result: 8
# Float Result: 2.5
# Mixed Result: 6.0
# Integer Division: 3.5
# Float Division: 3.5
# Power Result: 8
# Remainder: 1

# %% [markdown]
# # *Importing python libraries*
#
# *   Numpy
# *   Matplotlib
# *   Pandas
# *   Tensorflow
# *   Keras

# %%
# numpy library: this is a sophisticated way to wor with arrays in python
import numpy as np
# Creating NumPy Arrays
array1 = np.array([1, 2, 3, 4, 5])
array2 = np.array([2, 4, 6, 8, 10])

# %%
# Basic Operations
sum_array = array1 + array2
difference_array = array2 - array1
product_array = array1 * array2
quotient_array = array2 / array1

# Broadcasting: Operations on entire arrays
scaled_array = array1 * 2

# Universal Functions (ufunc)
square_root_array = np.sqrt(array1)
exponential_array = np.exp(array1)
sin_array = np.sin(array1)

# Dot Product
dot_product = np.dot(array1, array2)

# Printing Results
print("Array 1:", array1)
print("Array 2:", array2)
print("Sum:", sum_array)
print("Difference:", difference_array)
print("Product:", product_array)
print("Quotient:", quotient_array)
print("Scaled Array:", scaled_array)
print("Square Root:", square_root_array)
print("Exponential:", exponential_array)
print("Sin:", sin_array)
print("Dot Product:", dot_product)
# Out:
# Array 1: [1 2 3 4 5]
# Array 2: [ 2  4  6  8 10]
# Sum: [ 3  6  9 12 15]
# Difference: [1 2 3 4 5]
# Product: [ 2  8 18 32 50]
# Quotient: [2. 2. 2. 2. 2.]
# Scaled Array: [ 2  4  6  8 10]
# Square Root: [1.         1.41421356 1.73205081 2.         2.23606798]
# Exponential: [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]
# Sin: [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# Dot Product: 110

# %% [markdown]
# # **Matplotlib library**

# %%
import matplotlib.pyplot as plt
from ast import increment_lineno

# %%
#backends - some magic commands behind the scene, as soon as I make changes updates the code don't wait for me to run
# %matplotlib inline

# %%
x = np.linspace(0,1,20)
x
# Out:
# array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ])

# %%
y = x
y
# Out:
# array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ])

# %%
plt.figure(figsize=(4,3),dpi=200)
plt.plot(x,y,linewidth=2)
plt.plot(x,x**3, 'r+',label='cubic')
plt.plot(x,np.cos(np.pi*x),'b-.', label='cosine', marker='d',markersize='5')
plt.xlabel('time', fontsize='small')
plt.ylabel('am', fontsize='small')
plt.legend(fontsize='small')
plt.tick_params(axis='both',labelsize=8)
plt.grid(True, linestyle='--', alpha=0.7)

# %%
plt.figure(figsize=(4,3),dpi=200)
# Plotting on the first subplot
plt.subplot(1,2,1)
plt.suptitle('title1')
plt.plot(x,y,linewidth=2)
plt.plot(x,x**3, 'r+',label='cubic')
plt.plot(x,np.cos(np.pi*x),'b-.', label='cosine', marker='d',markersize='5')
plt.xlabel('time', fontsize='small')
plt.ylabel('am', fontsize='small')
plt.legend(fontsize='small')
plt.tick_params(axis='both',labelsize=8)
plt.grid(True, linestyle='--', alpha=0.7)
# Plotting on the second subplot
plt.subplot(1,2,2)
plt.suptitle('title goes here')
plt.plot(x,y,linewidth=2)
plt.plot(x,x**2, 'r+',label='cubic')
plt.plot(x,np.sin(np.pi*x),'b-.', label='cosine', marker='d',markersize='5')
plt.xlabel('time', fontsize='small')
plt.ylabel('am', fontsize='small')
plt.legend(fontsize='small')
plt.tick_params(axis='both',labelsize=8)
plt.grid(True, linestyle='--', alpha=0.7)

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.linspace(0,1,20)
fig,ax=plt.subplots(figsize=(4,2), dpi=200)
ax.plot(x,x**2,linewidth=2)

# %%
x= np.linspace(0,1,20)
fig1,ax1 =plt.subplots(1,2,figsize=(4,2),dpi=200)
fig1.suptitle('title goes here')
# Plotting on the first subplot
ax1[0].plot(x,x**2)
ax1[0].grid(True, linestyle='--', alpha=0.7)  # Adding grid lines
ax1[0].legend(fontsize='small')
# Plotting on the second subplot
ax1[1].plot(x,np.cos(x))
ax1[1].grid(True, linestyle='--', alpha=0.7)  # Adding grid lines
plt.tight_layout(rect=[0, 0.03, 1, 0.95])     # Adjusting layout
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
